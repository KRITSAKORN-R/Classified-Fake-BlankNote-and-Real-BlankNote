# %% [markdown]
# # **ทำการติดตั้ง Packages ที่จำเป็น**

# %%
pip install tensorflowjs

# %%
pip install graphviz

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.models import load_model
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %% [markdown]
# # Mounted Google Drive

# %%
from google.colab import drive #case mounted gdrive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os  #case connect via OS
os.chdir("/content/gdrive/")
os.getcwd()
# Out:
# '/content/gdrive'

# %% [markdown]
# # สร้างตัวแปร List X , y สำหรับใส่ข้อมูลรูปภาพและคำเฉลย

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from PIL import Image

X =  []
y = []

# %% [markdown]
# # กำหนดชื่อคลาสแต่ละคลาส

# %%
class_name = ["Real", "Fake"]

# %% [markdown]
# # นำเข้าข้อมูลรูปภาพ ธนบัตรจริง แล้วมาแปลงให้เป็น Array

# %%
path_Real = "/content/gdrive/MyDrive/Colab Notebooks/Banknote/Real banknote"
files_Real = os.listdir(path_Real)

for filename in files_Real:
    print(path_Real+"/"+filename)

    img = load_img(path_Real+"/"+filename)

    img_array = img_to_array(img)

    X.append(img_array)
    y.append([1, 0])

# %% [markdown]
# # นำเข้าข้อมูลรูปภาพ ธนบัตรปลอม แล้วมาแปลงให้เป็น Array

# %%
path_Fake = "/content/gdrive/MyDrive/Colab Notebooks/Banknote/Fake banknote"
files_Fake = os.listdir(path_Fake)

for filename in files_Fake:
    print(path_Fake+"/"+filename)

    img = load_img(path_Fake+"/"+filename)

    img_array = img_to_array(img)

    X.append(img_array)
    y.append([0, 1])

# %% [markdown]
# #นำตัวแปร List X , y มาทำให้เป็น Array

# %%
import numpy as np
X = np.array(X)
y = np.array(y)

# %% [markdown]
# #ทำการกำหนดรูปแบบของตัวแปร X เป็น 4 มิติ โดยแต่ละมิติเท่ากับ 200x200x3

# %%
X = X.reshape(len(y),200,200,3)
x_vector = 200*200*3

# %% [markdown]
# # เอาข้อมูลรูปภาพมา Plot Graph

# %%
plt.rcParams['figure.figsize'] = (10,10)

for i in range(16):
    plt.subplot(4,4,i+1)
    img_array = X[i]
    plt.imshow(np.uint8(img_array))
    cl = np.argmax(y[i])
    plt.title("Class {}".format(class_name[cl]))

plt.tight_layout()

# %% [markdown]
# #แบ่งชุดข้อมูล Train , Test อัตราส่วน 80 : 20

# %%
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.20, random_state=1000)
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (800, 200, 200, 3)
# y_train shape (800, 2)
# X_test shape (200, 200, 200, 3)
# y_test shape (200, 2)

# %% [markdown]
# # กำหนดจำนวนของคลาส

# %%
nb_classes = 2 # number of unique classes

# %% [markdown]
# #Normalization

# %%
X_train= X_train / 255.0

X_test = X_test / 255.0

# %% [markdown]
# # Custom Model MobileNet

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNet
from tensorflow.keras import regularizers

# Load the MobileNet model with pre-trained weights from ImageNet
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(200, 200, 3))

# Add a new fully connected layer for classification
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = Dense(128,kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
x = Dropout(0.20)(x)
x = Dense(64,kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
x = Dropout(0.20)(x)
x = Dense(32,kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
x = Dropout(0.25)(x)
x = Flatten()(x)
predictions = Dense(2, activation='softmax')(x)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step

# %% [markdown]
# #Compile Model

# %%
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #Fit Model

# %%
history = model.fit(X_train, y_train, batch_size=20, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 40/40 [==============================] - 157s 4s/step - loss: 3.0564 - accuracy: 0.9137 - val_loss: 2.2647 - val_accuracy: 0.9750
# Epoch 2/50
# 40/40 [==============================] - 137s 3s/step - loss: 1.7371 - accuracy: 0.9638 - val_loss: 1.2559 - val_accuracy: 0.9850
# Epoch 3/50
# 40/40 [==============================] - 143s 4s/step - loss: 1.0062 - accuracy: 0.9912 - val_loss: 0.7394 - val_accuracy: 1.0000
# Epoch 4/50
# 40/40 [==============================] - 141s 4s/step - loss: 0.6514 - accuracy: 0.9837 - val_loss: 0.4878 - val_accuracy: 0.9950
# Epoch 5/50
# 40/40 [==============================] - 140s 4s/step - loss: 0.4613 - accuracy: 0.9800 - val_loss: 0.6017 - val_accuracy: 0.9600
# Epoch 6/50
# 40/40 [==============================] - 141s 4s/step - loss: 0.3110 - accuracy: 0.9912 - val_loss: 0.6540 - val_accuracy: 0.9300
# Epoch 7/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.2147 - accuracy: 0.9987 - val_loss: 0.1766 - val_accuracy: 1.0000
# Epoch 8/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.2249 - accuracy: 0.9762 - val_loss: 0.6178 - val_accuracy: 0.9000
# Epoch 9/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.1535 - accuracy: 0.9925 - val_loss: 0.2114 - val_accuracy: 0.9900
# Epoch 10/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.1197 - accuracy: 0.9950 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 11/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.1383 - accuracy: 0.9837 - val_loss: 0.1079 - val_accuracy: 0.9900
# Epoch 12/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0848 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 13/50
# 40/40 [==============================] - 147s 4s/step - loss: 0.0745 - accuracy: 0.9975 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 14/50
# 40/40 [==============================] - 140s 4s/step - loss: 0.0778 - accuracy: 0.9925 - val_loss: 0.0530 - val_accuracy: 1.0000
# Epoch 15/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0590 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 16/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0507 - accuracy: 0.9987 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 17/50
# 40/40 [==============================] - 140s 4s/step - loss: 0.0450 - accuracy: 0.9987 - val_loss: 0.0480 - val_accuracy: 0.9950
# Epoch 18/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0431 - accuracy: 0.9975 - val_loss: 0.0494 - val_accuracy: 0.9950
# Epoch 19/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9850
# Epoch 20/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 21/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0423 - accuracy: 0.9950 - val_loss: 0.0478 - val_accuracy: 0.9950
# Epoch 22/50
# 40/40 [==============================] - 139s 3s/step - loss: 0.1074 - accuracy: 0.9812 - val_loss: 2.2041 - val_accuracy: 0.6950
# Epoch 23/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.1100 - accuracy: 0.9875 - val_loss: 0.1180 - val_accuracy: 0.9850
# Epoch 24/50
# 40/40 [==============================] - 141s 4s/step - loss: 0.0864 - accuracy: 0.9875 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 25/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0552 - accuracy: 0.9950 - val_loss: 0.0578 - val_accuracy: 0.9900
# Epoch 26/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0575 - accuracy: 0.9925 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 27/50
# 40/40 [==============================] - 145s 4s/step - loss: 0.0875 - accuracy: 0.9825 - val_loss: 0.0626 - val_accuracy: 0.9950
# Epoch 28/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0423 - accuracy: 0.9987 - val_loss: 0.0621 - val_accuracy: 0.9900
# Epoch 29/50
# 40/40 [==============================] - 138s 3s/step - loss: 0.0555 - accuracy: 0.9925 - val_loss: 0.0611 - val_accuracy: 0.9950
# Epoch 30/50
# 40/40 [==============================] - 138s 3s/step - loss: 0.0404 - accuracy: 0.9975 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 31/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0399 - accuracy: 0.9950 - val_loss: 0.0515 - val_accuracy: 0.9850
# Epoch 32/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9950
# Epoch 33/50
# 40/40 [==============================] - 138s 3s/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 0.9950
# Epoch 34/50
# 40/40 [==============================] - 139s 4s/step - loss: 0.0340 - accuracy: 0.9975 - val_loss: 0.0367 - val_accuracy: 0.9950
# Epoch 35/50
# 40/40 [==============================] - 141s 4s/step - loss: 0.0448 - accuracy: 0.9962 - val_loss: 0.0613 - val_accuracy: 0.9900
# Epoch 36/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0366 - accuracy: 0.9975 - val_loss: 0.0567 - val_accuracy: 0.9950
# Epoch 37/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0579 - accuracy: 0.9900 - val_loss: 0.1419 - val_accuracy: 0.9700
# Epoch 38/50
# 40/40 [==============================] - 140s 4s/step - loss: 0.0462 - accuracy: 0.9950 - val_loss: 0.0666 - val_accuracy: 0.9800
# Epoch 39/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0463 - accuracy: 0.9925 - val_loss: 0.0340 - val_accuracy: 0.9950
# Epoch 40/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0352 - accuracy: 0.9975 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 41/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0708 - accuracy: 0.9887 - val_loss: 0.0678 - val_accuracy: 0.9900
# Epoch 42/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9950
# Epoch 43/50
# 40/40 [==============================] - 138s 3s/step - loss: 0.0303 - accuracy: 0.9987 - val_loss: 0.0433 - val_accuracy: 0.9900
# Epoch 44/50
# 40/40 [==============================] - 141s 4s/step - loss: 0.0518 - accuracy: 0.9962 - val_loss: 0.0457 - val_accuracy: 0.9950
# Epoch 45/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9900
# Epoch 46/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 47/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 48/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0434 - accuracy: 0.9962 - val_loss: 0.0349 - val_accuracy: 0.9950
# Epoch 49/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 50/50
# 40/40 [==============================] - 136s 3s/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000

# %% [markdown]
# #Show Train Loss & Accuracy

# %%
score_train = model.evaluate(X_train, y_train, verbose = 0)
print('Train loss : ', score_train[0])
print('Train accuracy : ',score_train[1])
# Out:
# Train loss :  0.017921360209584236
# Train accuracy :  1.0

# %% [markdown]
# #Show Test Loss & Accuracy

# %%
score_test = model.evaluate(X_test, y_test, verbose = 0)
print('Test loss : ', score_test[0])
print('Test accuracy : ', score_test[1])
# Out:
# Test loss :  0.01992441527545452
# Test accuracy :  1.0

# %% [markdown]
# #Plot Graph Loss & Accuracy of Train Test

# %%
import matplotlib.pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, color='red', label='Training acc')
plt.plot(epochs, val_acc, color='green', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# #Classification Report

# %%
val_pred = model.predict(X_test)
val_pred_classes = np.argmax(val_pred, axis=1)
val_true_classes = np.argmax(y_test, axis=1)
# Out:
# 7/7 [==============================] - 6s 749ms/step

# %%
from keras.callbacks import ModelCheckpoint
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
accuracy = accuracy_score(val_true_classes, val_pred_classes)
print('Accuracy: %f' % accuracy)

precision = precision_score(val_true_classes, val_pred_classes)
print('Precision: %f' % precision)

recall = recall_score(val_true_classes, val_pred_classes)
print('Recall: %f' % recall)

f1 = f1_score(val_true_classes, val_pred_classes)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 1.000000
# Precision: 1.000000
# Recall: 1.000000
# F1 score: 1.000000

# %%
kappa = cohen_kappa_score(val_true_classes, val_pred_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(val_true_classes, val_pred_classes)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(val_true_classes, val_pred_classes)
print(matrix)
# Out:
# Cohens kappa: 1.000000
# ROC AUC: 1.000000
# [[ 94   0]
#  [  0 106]]

# %% [markdown]
# #ทำการ Predict กับข้อมูลชุด Test Set

# %%
yhat_probs = model.predict(X_test, verbose=0)
yhat_classes = np.argmax(yhat_probs, axis=1)
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes

# %%
test_predict = tf.keras.Sequential([model,tf.keras.layers.Softmax()])
result = test_predict.predict(X_test)
for i in range(20):
  print(class_name[int(np.argmax(result[i]))])
# Out:
# 7/7 [==============================] - 7s 749ms/step
# Fake
# Fake
# Real
# Real
# Fake
# Fake
# Fake
# Real
# Fake
# Fake
# Fake
# Fake
# Real
# Real
# Real
# Fake
# Fake
# Fake
# Real
# Fake

# %%
test_img = np.squeeze(X_test[8])
print(X_test.shape)
plt.figure()
plt.imshow(test_img)
plt.colorbar()
cl = np.argmax(result[8])
plt.title("Class {}".format(class_name[cl]))
plt.grid(True)
plt.show()
# Out:
# (200, 200, 200, 3)

# %% [markdown]
# #Save Model

# %%
#model.save("/content/gdrive/MyDrive/Colab Notebooks/Classifiled_Banknote/banknote_mobilenet.h5")
print("Saved model.")
# Out:
# Saved model.

# %% [markdown]
# #Show Model Visualize

# %%
pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (8.4.0)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.16-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.0/992.0 KB 16.4 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import visualkeras
visualkeras.layered_view(model)
from tensorflow.keras import layers
from collections import defaultdict
color_map = defaultdict(dict)
color_map[layers.Conv2D]['fill'] = '#00f5d4'
color_map[layers.MaxPooling2D]['fill'] = '#8338ec'
color_map[layers.Dropout]['fill'] = '#03045e'
color_map[layers.Dense]['fill'] = '#fb5607'
color_map[layers.Flatten]['fill'] = '#ffbe0b'
visualkeras.layered_view(model, legend=True,color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=5048x1103 at 0x7F3C17E46E50>
